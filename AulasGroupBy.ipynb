# %%
import pandas as pd

# %%
covid = pd.read_csv('covid.csv', sep=';')
covid
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
covid.loc[0,'regiao']
# Out:
# 'Brasil'

# %%
covid.loc[:, ['regiao', 'coduf', 'estado', 'municipio']]
# Out:
#               regiao  coduf estado municipio
# 0             Brasil     76    NaN       NaN
# 1             Brasil     76    NaN       NaN
# 2             Brasil     76    NaN       NaN
# 3             Brasil     76    NaN       NaN
# 4             Brasil     76    NaN       NaN
# ...              ...    ...    ...       ...
# 471991  Centro-Oeste     53     DF  Brasília
# 471992  Centro-Oeste     53     DF  Brasília
# 471993  Centro-Oeste     53     DF  Brasília
# 471994  Centro-Oeste     53     DF  Brasília
# 471995  Centro-Oeste     53     DF  Brasília
#
# [471996 rows x 4 columns]

# %%
covid.loc[0:10, ['regiao']]
# Out:
#     regiao
# 0   Brasil
# 1   Brasil
# 2   Brasil
# 3   Brasil
# 4   Brasil
# 5   Brasil
# 6   Brasil
# 7   Brasil
# 8   Brasil
# 9   Brasil
# 10  Brasil

# %%
covid.loc[0:10, :]
# Out:
#     regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 5   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 6   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 7   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 8   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 9   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 10  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
# ...

# %%
covid.loc[:,:]
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
covid.loc[0:10, 'regiao':'semanaEpi']
# Out:
#     regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 5   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 6   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 7   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 8   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 9   Brasil    NaN       NaN     76     NaN             NaN             NaN
# 10  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#           data  semanaEpi
# 0   2022-07-01         26
# ...

# %%
coduf_filtrado = covid[covid['coduf'] == 53]
coduf_filtrado

# covid.loc[(covid['estado'] == 'MS') & (covid['regiao'] == 'Centro-Oeste')]

covid.loc[(covid['estado'] == 'MS') | (covid['regiao'] == 'Centro-Oeste')]
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 2016    Centro-Oeste     MS       NaN     50       NaN             NaN
# 2017    Centro-Oeste     MS       NaN     50       NaN             NaN
# 2018    Centro-Oeste     MS       NaN     50       NaN             NaN
# 2019    Centro-Oeste     MS       NaN     50       NaN             NaN
# 2020    Centro-Oeste     MS       NaN     50       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
covid2 = covid.copy()
covid2
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
covid2.loc[0:10, 'regiao'] = 'teste'
covid2.head()
# Out:
#   regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  teste    NaN       NaN     76     NaN             NaN             NaN
# 1  teste    NaN       NaN     76     NaN             NaN             NaN
# 2  teste    NaN       NaN     76     NaN             NaN             NaN
# 3  teste    NaN       NaN     76     NaN             NaN             NaN
# 4  teste    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2022-07-01         26       210147125.0        32434063       76045
# 1  2022-07-02         26       210147125.0        32471847       37784
# 2  2022-07-03         27       210147125.0        32490422       18575
# 3  2022-07-04         27       210147125.0        32535923       45501
# 4  2022-07-05         27       210147125.0        32610514       74591
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %%
covid.iloc[0].to_frame()
# Out:
#                                   0
# regiao                       Brasil
# estado                          NaN
# municipio                       NaN
# coduf                            76
# codmun                          NaN
# codRegiaoSaude                  NaN
# nomeRegiaoSaude                 NaN
# data                     2022-07-01
# semanaEpi                        26
# populacaoTCU2019        210147125.0
# casosAcumulado             32434063
# casosNovos                    76045
# obitosAcumulado              671700
# obitosNovos                     284
# Recuperadosnovos         30873682.0
# emAcompanhamentoNovos      888681.0
# interior/metropolitana          NaN
# (0, regiao)                   teste

# %%
covid.iloc[0,0]
# Out:
# 'Brasil'

# %%
covid.iloc[0].to_frame().T
# Out:
#    regiao estado municipio coduf codmun codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN    76    NaN            NaN             NaN
#
#          data semanaEpi populacaoTCU2019 casosAcumulado casosNovos  \
# 0  2022-07-01        26      210147125.0       32434063      76045
#
#   obitosAcumulado obitosNovos Recuperadosnovos emAcompanhamentoNovos  \
# 0          671700         284       30873682.0              888681.0
#
#   interior/metropolitana (0, regiao)
# 0                    NaN       teste

# %%
covid.iloc[-5:, ]
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 471991  DISTRITO FEDERAL  2022-09-18         38         3015268.0
# 471992  DISTRITO FEDERAL  2022-09-19         38         3015268.0
# 471993  DISTRITO FEDERAL  2022-09-20         38         3015268.0
# 471994  DISTRITO FEDERAL  2022-09-21         38         3015268.0
# 471995  DISTRITO FEDERAL  2022-09-22         38         3015268.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 471991          838413           0            11825            0
# ...

# %%
covid['estado'].value_counts()
# Out:
# MG    71820
# SP    54348
# RS    41916
# BA    35196
# PR    33684
# SC    24948
# GO    20832
# PI    18984
# PB    18900
# MA    18396
# PE    15708
# CE    15624
# RN    14196
# PA    12180
# MT    12012
# TO    11844
# AL     8736
# RJ     7896
# MS     6720
# ES     6720
# SE     6468
# AM     5292
# RO     4536
# AC     1932
# AP     1428
# RR     1428
# DF      168
# Name: estado, dtype: int64

# %% [markdown]
# # 1 - Questão
# Utilizando a função loc, filtre toda tabela, porém somente aonde o estado for o ceará (CE)

# %%
ce = covid.loc[covid['estado'] == 'CE', :]
ce
# Out:
#          regiao estado        municipio  coduf    codmun  codRegiaoSaude  \
# 840    Nordeste     CE              NaN     23       NaN             NaN
# 841    Nordeste     CE              NaN     23       NaN             NaN
# 842    Nordeste     CE              NaN     23       NaN             NaN
# 843    Nordeste     CE              NaN     23       NaN             NaN
# 844    Nordeste     CE              NaN     23       NaN             NaN
# ...         ...    ...              ...    ...       ...             ...
# 93151  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93152  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93153  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93154  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93155  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# # 2 - Questão
# Agora com o estado filtrado pegue o municipio de fortaleza

# %%
ce.loc[ce['municipio'] == 'Fortaleza']
# Out:
#          regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 82572  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82573  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82574  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82575  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82576  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# ...         ...    ...        ...    ...       ...             ...
# 82651  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82652  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82653  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82654  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82655  Nordeste     CE  Fortaleza     23  230440.0         23001.0
#
#            nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 82572  1ª REGIAO FORTALEZA  2022-07-01         26         2669342.0
# ...

# %% [markdown]
# # 3 - Questão
# Filtre os estados que estejam com a semana epidemiológica acima de 30 __e__ que sejam do Distrito Federal(DF)

# %%
df = covid.loc[(covid['semanaEpi'] > 30) & (covid['estado'] == 'DF')]
df
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 2298    Centro-Oeste     DF       NaN     53       NaN             NaN
# 2299    Centro-Oeste     DF       NaN     53       NaN             NaN
# 2300    Centro-Oeste     DF       NaN     53       NaN             NaN
# 2301    Centro-Oeste     DF       NaN     53       NaN             NaN
# 2302    Centro-Oeste     DF       NaN     53       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# # 4 - Questão
# Some agora a coluna de "obitosNovos" do distrito federal

# %%
df['obitosNovos'].sum()
# Out:
# 20

# %%
covid.describe()
# Out:
#                coduf         codmun  codRegiaoSaude      semanaEpi  \
# count  471996.000000  469644.000000   467880.000000  471996.000000
# mean       32.360384  325258.014130    32403.123698      32.214286
# std         9.873307   98535.129104     9836.351818       3.481490
# min        11.000000  110000.000000    11001.000000      26.000000
# 25%        25.000000  251200.000000    25010.000000      29.000000
# 50%        31.000000  314610.000000    31059.000000      32.000000
# 75%        41.000000  411915.000000    41015.000000      35.000000
# max        76.000000  530010.000000    53001.000000      38.000000
#
#        populacaoTCU2019  casosAcumulado     casosNovos  obitosAcumulado  \
# count      4.702320e+05    4.719960e+05  471996.000000    471996.000000
# mean       1.126190e+05    1.810664e+04      14.355865       363.115107
# std        2.935317e+06    4.701238e+05     511.199512      9572.018291
# min        7.810000e+02    0.000000e+00  -30211.000000         0.000000
# ...

# %%
data = {'turmas':['1A','1A','2A','2A','3A','3A','3A'],
        'alunos': ['Carlos','Grazi','Nator', 'Juci', 'Miguel', 'Aline', 'Emanuel'],
        'notas':[7,8,10,6,5,4.5,10]
        }
        
escola = pd.DataFrame(data)
escola
# Out:
#   turmas   alunos  notas
# 0     1A   Carlos    7.0
# 1     1A    Grazi    8.0
# 2     2A    Nator   10.0
# 3     2A     Juci    6.0
# 4     3A   Miguel    5.0
# 5     3A    Aline    4.5
# 6     3A  Emanuel   10.0

# %%
escola.mean()
# Out:
# <ipython-input-106-653bde871b38>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   escola.mean()
# notas    7.214286
# dtype: float64

# %%
escola.groupby('turmas').count()
# Out:
#         alunos  notas
# turmas
# 1A           2      2
# 2A           2      2
# 3A           3      3

# %%
escola.groupby("turmas").mean()
# Out:
#         notas
# turmas
# 1A        7.5
# 2A        8.0
# 3A        6.5

# %%
paises = pd.DataFrame({
    "country" : ["United States", "Canada", "United Kingdom", "France", "Germany", "China", "Japan", "South Korea"],
    "continent" : ["North America", "North America", "Europe", "Europe", "Europe", "Asia", "Asia", "Asia"],
    "population" : [332722557, 38711108, 67081234, 67853000, 83222442, 1412600000, 125502000, 51745000],
    "area" : [3796742, 3855100, 93628, 247368, 137882, 3705407, 145937, 38690],
    "population percentage of world": [4.18, 0.487, 0.843, 0.853, 1.05, 17.8, 1.58, 0.650]
})

paises
# Out:
#           country      continent  population     area  \
# 0   United States  North America   332722557  3796742
# 1          Canada  North America    38711108  3855100
# 2  United Kingdom         Europe    67081234    93628
# 3          France         Europe    67853000   247368
# 4         Germany         Europe    83222442   137882
# 5           China           Asia  1412600000  3705407
# 6           Japan           Asia   125502000   145937
# 7     South Korea           Asia    51745000    38690
#
#    population percentage of world
# 0                           4.180
# 1                           0.487
# 2                           0.843
# 3                           0.853
# 4                           1.050
# 5                          17.800
# 6                           1.580
# 7                           0.650

# %%
paises.groupby('continent').sum()
# Out:
#                population     area  population percentage of world
# continent
# Asia           1589847000  3890034                          20.030
# Europe          218156676   478878                           2.746
# North America   371433665  7651842                           4.667

# %%
paises.groupby('continent')[['population']].sum()
# Out:
#                population
# continent
# Asia           1589847000
# Europe          218156676
# North America   371433665

# %%
paises.groupby('continent')[['population','area']].sum().sort_values(by='population', ascending=False)
# Out:
#                population     area
# continent
# Asia           1589847000  3890034
# North America   371433665  7651842
# Europe          218156676   478878

# %%
loja = pd.read_csv('https://raw.githubusercontent.com/rafaelpuyau/infinity_school/main/ds/datasets/atividade_casa.csv')
loja
# Out:
#         Produto      Cor       Valor  Quantidade       Sexo  Idade  \
# 0         Calça     Roxa   66.947509           4  Masculino     39
# 1      Camiseta  Amarela   99.692292           1  Masculino     30
# 2         Calça     Azul   92.502413           2   Feminino     25
# 3         Short     Azul  162.693470           1   Feminino     45
# 4      Camiseta  Laranja  148.191049           3   Feminino     29
# ...         ...      ...         ...         ...        ...    ...
# 99995     Calça  Laranja  101.158897           4  Masculino     46
# 99996      Saia    Preta  100.815311           3  Masculino     28
# 99997     Calça     Azul   63.924217           4   Feminino     48
# 99998     Calça     Azul  149.062392           3   Feminino     19
# 99999      Saia    Verde  114.089710           3  Masculino     25
#
#       Data da Venda         Canal
# 0        2022-02-25  Loja Virtual
# 1        2022-01-19   Loja Física
# 2        2022-03-11   Loja Física
# ...

# %%
resultado = loja.groupby(['Produto', 'Cor']).agg( {'Valor': 'max', 'Idade': 
                                       ['sum','min','mean']} )
resultado
# Out:
#                         Valor  Idade
#                           max    sum min       mean
# Produto  Cor
# Calça    Amarela   179.983554  83153  18  33.570044
#          Azul      179.879813  85554  18  33.186191
#          Cinza     179.999629  83744  18  33.271355
#          Laranja   179.934841  88638  18  33.715481
#          Preta     179.844980  83723  18  33.610197
#          Roxa      179.996657  82503  18  33.280758
#          Verde     179.960123  83441  18  33.363055
#          Vermelha  179.945384  85990  18  33.602970
# Camisa   Amarela   179.917138  82451  18  33.327001
#          Azul      179.940290  83650  18  33.486789
#          Cinza     179.953572  79980  18  33.408521
#          Laranja   179.979988  85147  18  33.628357
#          Preta     179.985823  83218  18  33.528606
#          Roxa      179.962381  83181  18  33.594911
#          Verde     179.901529  84768  18  33.086651
#          Vermelha  179.952399  83133  18  33.173583
# ...

# %% [markdown]
# # 1 - Questão
#
# Agrupe os produtos e veja qual a média de valor cada um deles.
#
# produtos nessa tabela:
#
# *   Calça
# *   Camisa
# *   Camiseta
# *   Saia
# *   Short

# %%
loja.groupby('Produto')[['Valor']].mean()
# Out:
#                Valor
# Produto
# Calça     114.944747
# Camisa    115.817377
# Camiseta  115.103593
# Saia      114.897358
# Short     115.201277

# %% [markdown]
# # 2 - Questão
# Agrupe as roupas por cor e veja o somatorio da quantidade de roupas daquela cor respectiva. Em suma faça a quantidade de cada cor.

# %%
loja.groupby('Cor')[['Quantidade']].sum()
# Out:
#           Quantidade
# Cor
# Amarela        31059
# Azul           31574
# Cinza          30924
# Laranja        31891
# Preta          30904
# Roxa           30970
# Verde          31672
# Vermelha       31433

# %% [markdown]
# # 3 - Questão
#
# Veja a média de idade de homens e mulheres que compraram na loja

# %%
loja.groupby('Sexo')[['Idade']].mean()
# Out:
#               Idade
# Sexo
# Feminino   33.44073
# Masculino  33.44121

# %% [markdown]
# # 5 - Questão
#
# Filtre os __estados__ de São Paulo e o Estado de Minas Gerais e depois veja quantas vezes os estados apareceram
#
# Resposta:
# MG -> 71820
# <br>
# SP -> 54348

# %%
covid.loc[(covid['estado'] == 'MG') | (covid['estado'] == 'SP')]['estado'].value_counts()
# Out:
# MG    71820
# SP    54348
# Name: estado, dtype: int64
